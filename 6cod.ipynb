# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline
import pandas as pd
from collections import Counter
from scipy.interpolate import interp1d
from scipy.ndimage import gaussian_filter1d
from pathlib import Path
from urllib import request
from ppxf.ppxf import ppxf, robust_sigma
import ppxf.ppxf_util as util
import ppxf.sps_util as lib
from vorbin.voronoi_2d_binning import voronoi_2d_binning
from plotbin.display_bins import display_bins
from ppxf.ppxf_util import log_rebin
import os
from PIL import Image
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import math
import csv
from scipy import ndimage
import glob
from time import time 
from astropy.wcs import WCS
import matplotlib.ticker as ticker

# %%
output_voronoi='/home/sabrinadopico/Área de trabalho/análise3866/outputsvoronoi/'
output_ppxfb='/home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/'

# %%
# Definindo o WCS
wcs_params = {
    'CTYPE1': 'RA---TAN',     # Projeção tangente para RA
    'CTYPE2': 'DEC--TAN',     # Projeção tangente para Dec
    'CRPIX1': 3134.20381624,            # Ponto de referência para o eixo 1 (pixel)
    'CRPIX2': 2089.65827139703,            # Ponto de referência para o eixo 2 (pixel)
    'CRVAL1': 24.0925255955211,    # RA da estrela guia (graus)
    'CRVAL2': 13.9448116152325,    # Dec da estrela guia (graus)
    'CD1_1': -1.43037913232859E-05,            # Escala de RA (graus por pixel)
    'CD2_2': -1.43182793542337E-05,            # Escala de Dec (graus por pixel)
    'RADECSYS': 'FK5',        # Sistema de coordenadas
    'EQUINOX': 2000.0         # Equinócio do sistema de coordenadas
}

wcs = WCS(naxis=2)  # Dois eixos, RA e Dec
wcs.wcs.ctype = [wcs_params['CTYPE1'], wcs_params['CTYPE2']]
wcs.wcs.crpix = [wcs_params['CRPIX1'], wcs_params['CRPIX2']]
wcs.wcs.crval = [wcs_params['CRVAL1'], wcs_params['CRVAL2']]
wcs.wcs.cd = [[wcs_params['CD1_1'], 0], [0, wcs_params['CD2_2']]]
wcs.wcs.radesys = wcs_params['RADECSYS']
wcs.wcs.equinox = wcs_params['EQUINOX']

coord_file = output_voronoi+'voronoi_n2.txt'  
coord_data = pd.read_csv(coord_file, delim_whitespace=True)

bin_velocities = {}
output_dir = output_ppxfb 
for bin_num in coord_data['BIN_NUM'].unique():
    print(bin_num)
    bin_file = f'{output_dir}espectro_bin{bin_num}.txt_1comp.out'
    print(bin_file)
    with open(bin_file, 'r') as f:
        lines = f.readlines()
        vgas_line = lines[12]  # 13ª linha (índice 12)
        vgas_value = float(vgas_line.split('=')[1].split()[0])
        #print(vgas_value)
        bin_velocities[bin_num] = vgas_value
x_max = int(coord_data['X'].max()) + 1
y_max = int(coord_data['Y'].max()) + 1
velocity_map = np.full((y_max, x_max), np.nan)  
for index, row in coord_data.iterrows():
    x, y, bin_num = int(row['X']), int(row['Y']), row['BIN_NUM']
    if bin_num in bin_velocities:
        velocity_map[y, x] = bin_velocities[bin_num]


# Gerando as coordenadas de pixel
pixels_x, pixels_y = np.meshgrid(np.arange(x_max), np.arange(y_max), indexing='xy')

# Convertendo para coordenadas RA e Dec
ra_dec = wcs.all_pix2world(pixels_x.flatten(), pixels_y.flatten(), 1)


# Ajuste os limites para garantir que o campo de visão esteja correto
ra_min, ra_max = ra_dec[0].min(), ra_dec[0].max()
dec_min, dec_max = ra_dec[1].min(), ra_dec[1].max()

# Se os valores forem muito amplos, tente ajustar manualmente ou verificar os dados
print(f"RA Min: {ra_min}, RA Max: {ra_max}")
print(f"Dec Min: {dec_min}, Dec Max: {dec_max}")


# Plotando o mapa com limites manuais
plt.figure(figsize=(8, 10))
plt.imshow(velocity_map, origin='lower', cmap='cividis', aspect='auto',
           extent=[ra_min, ra_max, dec_min, dec_max], vmax=22, vmin=-22)
plt.colorbar(label='Velocity (km/s)')
plt.xlabel('RA (degrees)')

plt.ylabel('Dec (degrees)')
plt.title('Radial velocity map')  # Inverter o eixo RA se necessário
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.ScalarFormatter(useOffset=False))
ax.xaxis.get_major_formatter().set_scientific(False)
ax.yaxis.set_major_formatter(ticker.ScalarFormatter(useOffset=False))
ax.yaxis.get_major_formatter().set_scientific(False)
plt.gca().invert_xaxis()  # Inverter o eixo RA se necessário
plt.show()
# Out:
# 19
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin19.txt_1comp.out
# 18
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin18.txt_1comp.out
# 20
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin20.txt_1comp.out
# 58
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin58.txt_1comp.out
# 26
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin26.txt_1comp.out
# 21
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin21.txt_1comp.out
# 16
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin16.txt_1comp.out
# 14
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin14.txt_1comp.out
# 13
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin13.txt_1comp.out
# 34
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin34.txt_1comp.out
# 12
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin12.txt_1comp.out
# 25
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin25.txt_1comp.out
# 15
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin15.txt_1comp.out
# 10
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin10.txt_1comp.out
# 11
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin11.txt_1comp.out
# 22
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin22.txt_1comp.out
# 6
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin6.txt_1comp.out
# 54
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin54.txt_1comp.out
# 5
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin5.txt_1comp.out
# 23
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin23.txt_1comp.out
# 83
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin83.txt_1comp.out
# 7
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin7.txt_1comp.out
# 8
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin8.txt_1comp.out
# 35
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin35.txt_1comp.out
# 4
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin4.txt_1comp.out
# 1
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin1.txt_1comp.out
# 27
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin27.txt_1comp.out
# 17
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin17.txt_1comp.out
# 0
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin0.txt_1comp.out
# 9
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin9.txt_1comp.out
# 24
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin24.txt_1comp.out
# 2
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin2.txt_1comp.out
# 37
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin37.txt_1comp.out
# 53
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin53.txt_1comp.out
# 29
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin29.txt_1comp.out
# 3
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin3.txt_1comp.out
# 28
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin28.txt_1comp.out
# 33
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin33.txt_1comp.out
# 32
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin32.txt_1comp.out
# 30
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin30.txt_1comp.out
# 31
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin31.txt_1comp.out
# 49
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin49.txt_1comp.out
# 68
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin68.txt_1comp.out
# 46
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin46.txt_1comp.out
# 39
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin39.txt_1comp.out
# 36
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin36.txt_1comp.out
# 38
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin38.txt_1comp.out
# 87
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin87.txt_1comp.out
# 59
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin59.txt_1comp.out
# 45
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin45.txt_1comp.out
# 41
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin41.txt_1comp.out
# 40
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin40.txt_1comp.out
# 55
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin55.txt_1comp.out
# 47
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin47.txt_1comp.out
# 44
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin44.txt_1comp.out
# 42
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin42.txt_1comp.out
# 43
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin43.txt_1comp.out
# 63
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin63.txt_1comp.out
# 56
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin56.txt_1comp.out
# 50
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin50.txt_1comp.out
# 48
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin48.txt_1comp.out
# 66
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin66.txt_1comp.out
# 57
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin57.txt_1comp.out
# 51
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin51.txt_1comp.out
# 52
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin52.txt_1comp.out
# 62
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin62.txt_1comp.out
# 86
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin86.txt_1comp.out
# 75
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin75.txt_1comp.out
# 65
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin65.txt_1comp.out
# 61
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin61.txt_1comp.out
# 60
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin60.txt_1comp.out
# 69
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin69.txt_1comp.out
# 64
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin64.txt_1comp.out
# 67
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin67.txt_1comp.out
# 78
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin78.txt_1comp.out
# 76
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin76.txt_1comp.out
# 72
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin72.txt_1comp.out
# 71
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin71.txt_1comp.out
# 70
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin70.txt_1comp.out
# 94
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin94.txt_1comp.out
# 82
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin82.txt_1comp.out
# 77
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin77.txt_1comp.out
# 73
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin73.txt_1comp.out
# 74
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin74.txt_1comp.out
# 85
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin85.txt_1comp.out
# 79
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin79.txt_1comp.out
# 84
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin84.txt_1comp.out
# 81
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin81.txt_1comp.out
# 80
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin80.txt_1comp.out
# 88
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin88.txt_1comp.out
# 89
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin89.txt_1comp.out
# 90
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin90.txt_1comp.out
# 93
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin93.txt_1comp.out
# 92
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin92.txt_1comp.out
# 98
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin98.txt_1comp.out
# 91
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin91.txt_1comp.out
# 97
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin97.txt_1comp.out
# 96
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin96.txt_1comp.out
# 95
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin95.txt_1comp.out
# 100
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin100.txt_1comp.out
# 99
# /home/sabrinadopico/Área de trabalho/análise3866/outputsppxfb/espectro_bin99.txt_1comp.out
# RA Min: 24.138252122924534, RA Max: 24.138723940784654
# Dec Min: 13.974040281655789, Dec Max: 13.974727647330598

# %%
wcs_params = {
    'CTYPE1': 'RA---TAN',     # Projeção tangente para RA
    'CTYPE2': 'DEC--TAN',     # Projeção tangente para Dec
    'CRPIX1': 3134.20381624,            # Ponto de referência para o eixo 1 (pixel)
    'CRPIX2': 2089.65827139703,            # Ponto de referência para o eixo 2 (pixel)
    'CRVAL1': 24.0925255955211,    # RA da estrela guia (graus)
    'CRVAL2': 13.9448116152325,    # Dec da estrela guia (graus)
    'CD1_1': -1.43037913232859E-05,            # Escala de RA (graus por pixel)
    'CD2_2': -1.43182793542337E-05,            # Escala de Dec (graus por pixel)
    'RADECSYS': 'FK5',        # Sistema de coordenadas
    'EQUINOX': 2000.0         # Equinócio do sistema de coordenadas
}

wcs = WCS(naxis=2)  # Dois eixos, RA e Dec
wcs.wcs.ctype = [wcs_params['CTYPE1'], wcs_params['CTYPE2']]
wcs.wcs.crpix = [wcs_params['CRPIX1'], wcs_params['CRPIX2']]
wcs.wcs.crval = [wcs_params['CRVAL1'], wcs_params['CRVAL2']]
wcs.wcs.cd = [[wcs_params['CD1_1'], 0], [0, wcs_params['CD2_2']]]
wcs.wcs.radesys = wcs_params['RADECSYS']
wcs.wcs.equinox = wcs_params['EQUINOX']

coord_file = output_voronoi+'voronoi_n2.txt' # Substituir pelo caminho do arquivo
coord_data = pd.read_csv(coord_file, delim_whitespace=True)
bin_velocities = {}
output_dir = output_ppxfb 

for bin_num in coord_data['BIN_NUM'].unique():
    bin_file = f'{output_dir}/espectro_bin{bin_num}.txt_1comp.out'
    with open(bin_file, 'r') as f:
        lines = f.readlines()
        vgas_line = lines[12]  # 13ª linha (índice 12)
        vgas_value = float(vgas_line.split('sigma=')[1].split()[0])
        bin_velocities[bin_num] = vgas_value
        #print(vgas_value)
x_max = int(coord_data['X'].max()) + 1
y_max = int(coord_data['Y'].max()) + 1
velocity_map = np.full((y_max, x_max), np.nan)  
for index, row in coord_data.iterrows():
    x, y, bin_num = int(row['X']), int(row['Y']), row['BIN_NUM']
    if bin_num in bin_velocities:
        velocity_map[y, x] = bin_velocities[bin_num]


# Gerando as coordenadas de pixel
pixels_x, pixels_y = np.meshgrid(np.arange(x_max), np.arange(y_max), indexing='xy')

# Convertendo para coordenadas RA e Dec
ra_dec = wcs.all_pix2world(pixels_x.flatten(), pixels_y.flatten(), 1)


# Ajuste os limites para garantir que o campo de visão esteja correto
ra_min, ra_max = ra_dec[0].min(), ra_dec[0].max()
dec_min, dec_max = ra_dec[1].min(), ra_dec[1].max()

# Se os valores forem muito amplos, tente ajustar manualmente ou verificar os dados
print(f"RA Min: {ra_min}, RA Max: {ra_max}")
print(f"Dec Min: {dec_min}, Dec Max: {dec_max}")


# Plotando o mapa com limites manuais
plt.figure(figsize=(8, 10))
plt.imshow(velocity_map, origin='lower', cmap='cividis', aspect='auto',
           extent=[ra_min, ra_max, dec_min, dec_max], vmin=22, vmax=45)
plt.colorbar(label='Velocity Dispersion')
plt.xlabel('RA (degrees)')

plt.ylabel('Dec (degrees)')
plt.title('Velocity Dispersion')  # Inverter o eixo RA se necessário
ax = plt.gca()
ax.xaxis.set_major_formatter(ticker.ScalarFormatter(useOffset=False))
ax.xaxis.get_major_formatter().set_scientific(False)
ax.yaxis.set_major_formatter(ticker.ScalarFormatter(useOffset=False))
ax.yaxis.get_major_formatter().set_scientific(False)
plt.gca().invert_xaxis()  # Inverter o eixo RA se necessário
plt.show()
# Out:
# RA Min: 24.138252122924534, RA Max: 24.138723940784654
# Dec Min: 13.974040281655789, Dec Max: 13.974727647330598
